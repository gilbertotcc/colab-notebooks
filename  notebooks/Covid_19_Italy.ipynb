# %% [markdown]
# <a href="https://colab.research.google.com/github/gilbertotcc/colab-notebooks/blob/feat%2Fcovid-19-italy/%20notebooks/Covid_19_Italy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Codiv-19 Italy
#
# This notebook collects *some analysis* of that data about Covid-19
# pandemic in Italy. Source data comes from the GitHub repository
# [pcm-dpc/COVID-19](https://github.com/pcm-dpc/COVID-19).

# %%
import pandas as pd

LATEST_DATA_BY_REGION_CSV_URL = "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni-latest.csv"

current_data_by_region = pd.read_csv(LATEST_DATA_BY_REGION_CSV_URL)
current_data_by_region[["denominazione_regione", "nuovi_positivi"]]
# Out:
#     denominazione_regione  nuovi_positivi
# 0                 Abruzzo             510
# 1              Basilicata             218
# 2                Calabria             468
# 3                Campania            2924
# 4          Emilia-Romagna            2165
# 5   Friuli Venezia Giulia             864
# 6                   Lazio            2276
# 7                 Liguria             606
# 8               Lombardia            5389
# 9                  Marche             490
# 10                 Molise              79
# 11           P.A. Bolzano             410
# 12            P.A. Trento             229
# 13               Piemonte            3149
# 14                 Puglia            1737
# 15               Sardegna             375
# 16                Sicilia            1566
# 17                Toscana            1117
# 18                 Umbria             261
# 19          Valle d'Aosta             101
# 20                 Veneto            3418
